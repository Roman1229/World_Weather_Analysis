# %%
import random
from citipy import citipy 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from config import weather_api_key
from datetime import datetime
import time

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

  
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 769

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description= city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | luderitz
# Processing Record 2 of Set 1 | constitucion
# Processing Record 3 of Set 1 | hithadhoo
# Processing Record 4 of Set 1 | dujuma
# City not found. Skipping...
# Processing Record 5 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 1 | airai
# Processing Record 7 of Set 1 | hobart
# Processing Record 8 of Set 1 | san quintin
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | nabire
# Processing Record 11 of Set 1 | barrow
# Processing Record 12 of Set 1 | tuktoyaktuk
# Processing Record 13 of Set 1 | kahului
# Processing Record 14 of Set 1 | buariki
# City not found. Skipping...
# Processing Record 15 of Set 1 | kruisfontein
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | yellowknife
# Processing Record 18 of Set 1 | sorong
# Processing Record 19 of Set 1 | dingle
# Processing Record 20 of Set 1 | les cayes
# Processing Record 21 of Set 1 | korla
# Processing Record 22 of Set 1 | hambantota
# Processing Record 23 of Set 1 | victoria
# Processing Record 24 of Set 1 | leningradskiy
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | avarua
# Processing Record 27 of Set 1 | atuona
# Processing Record 28 of Set 1 | naze
# Processing Record 29 of Set 1 | severo-kurilsk
# Processing Record 30 of Set 1 | antofagasta
# Processing Record 31 of Set 1 | richards bay
# Processing Record 32 of Set 1 | port alfred
# Processing Record 33 of Set 1 | port elizabeth
# Processing Record 34 of Set 1 | karsun
# Processing Record 35 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 1 | clyde river
# Processing Record 37 of Set 1 | punta arenas
# Processing Record 38 of Set 1 | ukiah
# Processing Record 39 of Set 1 | berlevag
# Processing Record 40 of Set 1 | san pedro
# Processing Record 41 of Set 1 | vardo
# Processing Record 42 of Set 1 | canon city
# Processing Record 43 of Set 1 | olinda
# Processing Record 44 of Set 1 | rawson
# Processing Record 45 of Set 1 | brae
# Processing Record 46 of Set 1 | puerto ayora
# Processing Record 47 of Set 1 | torbay
# Processing Record 48 of Set 1 | mandalgovi
# Processing Record 49 of Set 1 | iskateley
# Processing Record 50 of Set 1 | dolbeau
# City not found. Skipping...
# Processing Record 1 of Set 2 | kapaa
# Processing Record 2 of Set 2 | mataura
# Processing Record 3 of Set 2 | lebu
# Processing Record 4 of Set 2 | saint-leu
# Processing Record 5 of Set 2 | klaksvik
# Processing Record 6 of Set 2 | valparaiso
# Processing Record 7 of Set 2 | harper
# Processing Record 8 of Set 2 | san cristobal
# Processing Record 9 of Set 2 | chaa-khol
# City not found. Skipping...
# Processing Record 10 of Set 2 | bluff
# Processing Record 11 of Set 2 | ponta do sol
# Processing Record 12 of Set 2 | hermanus
# Processing Record 13 of Set 2 | funtua
# Processing Record 14 of Set 2 | nikolskoye
# Processing Record 15 of Set 2 | tadine
# Processing Record 16 of Set 2 | jumla
# Processing Record 17 of Set 2 | honiara
# Processing Record 18 of Set 2 | saint george
# Processing Record 19 of Set 2 | necochea
# Processing Record 20 of Set 2 | albany
# Processing Record 21 of Set 2 | yumen
# Processing Record 22 of Set 2 | chernyshevskiy
# Processing Record 23 of Set 2 | georgetown
# Processing Record 24 of Set 2 | provideniya
# Processing Record 25 of Set 2 | dale
# Processing Record 26 of Set 2 | inuvik
# Processing Record 27 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 2 | quatre cocos
# Processing Record 29 of Set 2 | juneau
# Processing Record 30 of Set 2 | cidreira
# Processing Record 31 of Set 2 | bathsheba
# Processing Record 32 of Set 2 | khatanga
# Processing Record 33 of Set 2 | qaanaaq
# Processing Record 34 of Set 2 | chokurdakh
# Processing Record 35 of Set 2 | tahlequah
# Processing Record 36 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 2 | itarema
# Processing Record 38 of Set 2 | nsanje
# Processing Record 39 of Set 2 | kaeo
# Processing Record 40 of Set 2 | tiksi
# Processing Record 41 of Set 2 | bambous virieux
# Processing Record 42 of Set 2 | sept-iles
# Processing Record 43 of Set 2 | broken hill
# Processing Record 44 of Set 2 | kodiak
# Processing Record 45 of Set 2 | norman wells
# Processing Record 46 of Set 2 | chifeng
# Processing Record 47 of Set 2 | kuleshovka
# Processing Record 48 of Set 2 | nossa senhora das dores
# Processing Record 49 of Set 2 | new norfolk
# Processing Record 50 of Set 2 | jamestown
# Processing Record 1 of Set 3 | rikitea
# Processing Record 2 of Set 3 | vrangel
# Processing Record 3 of Set 3 | ancud
# Processing Record 4 of Set 3 | sao joao da barra
# Processing Record 5 of Set 3 | aparecida do taboado
# Processing Record 6 of Set 3 | syamzha
# Processing Record 7 of Set 3 | springbok
# Processing Record 8 of Set 3 | mahina
# Processing Record 9 of Set 3 | kingaroy
# Processing Record 10 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 3 | skagastrond
# City not found. Skipping...
# Processing Record 12 of Set 3 | okha
# Processing Record 13 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 3 | lorengau
# Processing Record 15 of Set 3 | champerico
# Processing Record 16 of Set 3 | cap-aux-meules
# Processing Record 17 of Set 3 | macae
# Processing Record 18 of Set 3 | saldanha
# Processing Record 19 of Set 3 | touros
# Processing Record 20 of Set 3 | tongchuan
# Processing Record 21 of Set 3 | katsuura
# Processing Record 22 of Set 3 | vanavara
# Processing Record 23 of Set 3 | nanortalik
# Processing Record 24 of Set 3 | litoral del san juan
# City not found. Skipping...
# Processing Record 25 of Set 3 | isla vista
# Processing Record 26 of Set 3 | mildura
# Processing Record 27 of Set 3 | mahebourg
# Processing Record 28 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 3 | tura
# Processing Record 30 of Set 3 | tanete
# Processing Record 31 of Set 3 | sangar
# Processing Record 32 of Set 3 | ratnagiri
# Processing Record 33 of Set 3 | ribeira grande
# Processing Record 34 of Set 3 | uaua
# Processing Record 35 of Set 3 | cape town
# Processing Record 36 of Set 3 | kidal
# Processing Record 37 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 3 | chuy
# Processing Record 39 of Set 3 | muros
# Processing Record 40 of Set 3 | cascais
# Processing Record 41 of Set 3 | tessalit
# Processing Record 42 of Set 3 | cap malheureux
# Processing Record 43 of Set 3 | fatsa
# Processing Record 44 of Set 3 | bengkulu
# Processing Record 45 of Set 3 | baruun-urt
# Processing Record 46 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 3 | waikuku
# Processing Record 48 of Set 3 | bredasdorp
# Processing Record 49 of Set 3 | sinazongwe
# Processing Record 50 of Set 3 | ostrovnoy
# Processing Record 1 of Set 4 | tottori
# Processing Record 2 of Set 4 | mount gambier
# Processing Record 3 of Set 4 | shubarkuduk
# Processing Record 4 of Set 4 | lixourion
# Processing Record 5 of Set 4 | mahibadhoo
# Processing Record 6 of Set 4 | fort saint john
# City not found. Skipping...
# Processing Record 7 of Set 4 | mbarara
# Processing Record 8 of Set 4 | dangara
# Processing Record 9 of Set 4 | celestun
# Processing Record 10 of Set 4 | mangrol
# Processing Record 11 of Set 4 | saint-philippe
# Processing Record 12 of Set 4 | ahipara
# Processing Record 13 of Set 4 | fortuna
# Processing Record 14 of Set 4 | hay river
# Processing Record 15 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 4 | hasaki
# Processing Record 17 of Set 4 | quelimane
# Processing Record 18 of Set 4 | florianopolis
# Processing Record 19 of Set 4 | lac du bonnet
# Processing Record 20 of Set 4 | ugoofaaru
# Processing Record 21 of Set 4 | sorland
# Processing Record 22 of Set 4 | mayor pablo lagerenza
# Processing Record 23 of Set 4 | seymchan
# Processing Record 24 of Set 4 | namibe
# Processing Record 25 of Set 4 | aketi
# Processing Record 26 of Set 4 | opuwo
# Processing Record 27 of Set 4 | nuuk
# Processing Record 28 of Set 4 | pevek
# Processing Record 29 of Set 4 | nizhnevartovsk
# Processing Record 30 of Set 4 | hilo
# Processing Record 31 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 4 | cutro
# Processing Record 33 of Set 4 | castro
# Processing Record 34 of Set 4 | mar del plata
# Processing Record 35 of Set 4 | butaritari
# Processing Record 36 of Set 4 | san lawrenz
# Processing Record 37 of Set 4 | tarko-sale
# Processing Record 38 of Set 4 | oloron-sainte-marie
# Processing Record 39 of Set 4 | esperance
# Processing Record 40 of Set 4 | karaton
# Processing Record 41 of Set 4 | dzaoudzi
# Processing Record 42 of Set 4 | thompson
# Processing Record 43 of Set 4 | longyearbyen
# Processing Record 44 of Set 4 | cabo san lucas
# Processing Record 45 of Set 4 | aquidauana
# Processing Record 46 of Set 4 | guerrero negro
# Processing Record 47 of Set 4 | mayo
# Processing Record 48 of Set 4 | borodino
# Processing Record 49 of Set 4 | dikson
# Processing Record 50 of Set 4 | sur
# Processing Record 1 of Set 5 | tres picos
# Processing Record 2 of Set 5 | east london
# Processing Record 3 of Set 5 | khandyga
# Processing Record 4 of Set 5 | nchelenge
# Processing Record 5 of Set 5 | agva
# City not found. Skipping...
# Processing Record 6 of Set 5 | latehar
# Processing Record 7 of Set 5 | sterling
# Processing Record 8 of Set 5 | manadhoo
# Processing Record 9 of Set 5 | half moon bay
# Processing Record 10 of Set 5 | iglesias
# Processing Record 11 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 5 | manoel urbano
# Processing Record 13 of Set 5 | coquimbo
# Processing Record 14 of Set 5 | vangaindrano
# Processing Record 15 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 16 of Set 5 | rio gallegos
# Processing Record 17 of Set 5 | lompoc
# Processing Record 18 of Set 5 | surgut
# Processing Record 19 of Set 5 | aguililla
# Processing Record 20 of Set 5 | davila
# Processing Record 21 of Set 5 | shimoda
# Processing Record 22 of Set 5 | san fernando
# Processing Record 23 of Set 5 | port hardy
# Processing Record 24 of Set 5 | acarau
# Processing Record 25 of Set 5 | caluquembe
# Processing Record 26 of Set 5 | cabra
# Processing Record 27 of Set 5 | vaitape
# Processing Record 28 of Set 5 | zabid
# Processing Record 29 of Set 5 | namatanai
# Processing Record 30 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 5 | nome
# Processing Record 32 of Set 5 | cuamba
# Processing Record 33 of Set 5 | port macquarie
# Processing Record 34 of Set 5 | lesnoy
# Processing Record 35 of Set 5 | hinton
# Processing Record 36 of Set 5 | poum
# Processing Record 37 of Set 5 | hirara
# Processing Record 38 of Set 5 | narsaq
# Processing Record 39 of Set 5 | vrnjacka banja
# Processing Record 40 of Set 5 | omboue
# Processing Record 41 of Set 5 | nanuque
# Processing Record 42 of Set 5 | north adams
# Processing Record 43 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 5 | chimbote
# Processing Record 45 of Set 5 | currais novos
# Processing Record 46 of Set 5 | pisco
# Processing Record 47 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 5 | cherskiy
# Processing Record 49 of Set 5 | penhold
# Processing Record 50 of Set 5 | orlik
# Processing Record 1 of Set 6 | port lincoln
# Processing Record 2 of Set 6 | linxia
# Processing Record 3 of Set 6 | alice springs
# Processing Record 4 of Set 6 | shepsi
# Processing Record 5 of Set 6 | safaga
# Processing Record 6 of Set 6 | lamu
# Processing Record 7 of Set 6 | junction city
# Processing Record 8 of Set 6 | xuddur
# Processing Record 9 of Set 6 | tiarei
# Processing Record 10 of Set 6 | hofn
# Processing Record 11 of Set 6 | maloshuyka
# City not found. Skipping...
# Processing Record 12 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 6 | mutata
# Processing Record 14 of Set 6 | los llanos de aridane
# Processing Record 15 of Set 6 | marawi
# Processing Record 16 of Set 6 | husavik
# Processing Record 17 of Set 6 | turukhansk
# Processing Record 18 of Set 6 | ler
# Processing Record 19 of Set 6 | flinders
# Processing Record 20 of Set 6 | naujamiestis
# Processing Record 21 of Set 6 | mentok
# City not found. Skipping...
# Processing Record 22 of Set 6 | makakilo city
# Processing Record 23 of Set 6 | huarmey
# Processing Record 24 of Set 6 | luena
# Processing Record 25 of Set 6 | andenes
# Processing Record 26 of Set 6 | tasiilaq
# Processing Record 27 of Set 6 | saint-augustin
# Processing Record 28 of Set 6 | ulaanbaatar
# Processing Record 29 of Set 6 | krasnogorsk
# Processing Record 30 of Set 6 | viedma
# Processing Record 31 of Set 6 | dzilam gonzalez
# Processing Record 32 of Set 6 | umm lajj
# Processing Record 33 of Set 6 | nouakchott
# Processing Record 34 of Set 6 | leh
# Processing Record 35 of Set 6 | kushiro
# Processing Record 36 of Set 6 | quballat
# Processing Record 37 of Set 6 | laguna
# Processing Record 38 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 39 of Set 6 | tuatapere
# Processing Record 40 of Set 6 | hovd
# Processing Record 41 of Set 6 | dandong
# Processing Record 42 of Set 6 | west bay
# Processing Record 43 of Set 6 | bentiu
# Processing Record 44 of Set 6 | moa
# Processing Record 45 of Set 6 | ilulissat
# Processing Record 46 of Set 6 | tres lagoas
# Processing Record 47 of Set 6 | rimbey
# Processing Record 48 of Set 6 | olafsvik
# Processing Record 49 of Set 6 | gat
# Processing Record 50 of Set 6 | simpang
# Processing Record 1 of Set 7 | talkha
# Processing Record 2 of Set 7 | bodrum
# Processing Record 3 of Set 7 | riverton
# Processing Record 4 of Set 7 | lasa
# Processing Record 5 of Set 7 | henties bay
# Processing Record 6 of Set 7 | salinas
# Processing Record 7 of Set 7 | mandera
# Processing Record 8 of Set 7 | kiama
# Processing Record 9 of Set 7 | portland
# Processing Record 10 of Set 7 | ust-kulom
# Processing Record 11 of Set 7 | miles city
# Processing Record 12 of Set 7 | evensk
# Processing Record 13 of Set 7 | iisalmi
# Processing Record 14 of Set 7 | saskylakh
# Processing Record 15 of Set 7 | ohara
# Processing Record 16 of Set 7 | douglas
# Processing Record 17 of Set 7 | northam
# Processing Record 18 of Set 7 | pangnirtung
# Processing Record 19 of Set 7 | yar-sale
# Processing Record 20 of Set 7 | itacoatiara
# Processing Record 21 of Set 7 | erenhot
# Processing Record 22 of Set 7 | faanui
# Processing Record 23 of Set 7 | puerto padre
# Processing Record 24 of Set 7 | grindavik
# Processing Record 25 of Set 7 | lyubim
# Processing Record 26 of Set 7 | pakaur
# Processing Record 27 of Set 7 | ambon
# Processing Record 28 of Set 7 | ampatuan
# Processing Record 29 of Set 7 | mariental
# Processing Record 30 of Set 7 | bethel
# Processing Record 31 of Set 7 | storslett
# Processing Record 32 of Set 7 | kavieng
# Processing Record 33 of Set 7 | talnakh
# Processing Record 34 of Set 7 | kavaratti
# Processing Record 35 of Set 7 | alibag
# Processing Record 36 of Set 7 | canutama
# Processing Record 37 of Set 7 | nevsehir
# Processing Record 38 of Set 7 | inhambane
# Processing Record 39 of Set 7 | amapa
# Processing Record 40 of Set 7 | pangai
# Processing Record 41 of Set 7 | karabash
# Processing Record 42 of Set 7 | madison
# Processing Record 43 of Set 7 | isangel
# Processing Record 44 of Set 7 | codrington
# Processing Record 45 of Set 7 | palauig
# Processing Record 46 of Set 7 | arraial do cabo
# Processing Record 47 of Set 7 | dossor
# Processing Record 48 of Set 7 | marystown
# Processing Record 49 of Set 7 | muroto
# Processing Record 50 of Set 7 | junagarh
# Processing Record 1 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 8 | trincomalee
# Processing Record 3 of Set 8 | moinesti
# Processing Record 4 of Set 8 | sisimiut
# Processing Record 5 of Set 8 | tabas
# Processing Record 6 of Set 8 | upernavik
# Processing Record 7 of Set 8 | padang
# Processing Record 8 of Set 8 | iracoubo
# Processing Record 9 of Set 8 | vila velha
# Processing Record 10 of Set 8 | jalu
# Processing Record 11 of Set 8 | waingapu
# Processing Record 12 of Set 8 | nishihara
# Processing Record 13 of Set 8 | jiazi
# Processing Record 14 of Set 8 | salalah
# Processing Record 15 of Set 8 | vila
# Processing Record 16 of Set 8 | iqaluit
# Processing Record 17 of Set 8 | vila do maio
# Processing Record 18 of Set 8 | pringsewu
# Processing Record 19 of Set 8 | ngunguru
# Processing Record 20 of Set 8 | sakaiminato
# Processing Record 21 of Set 8 | kuching
# Processing Record 22 of Set 8 | savannah bight
# Processing Record 23 of Set 8 | nemuro
# Processing Record 24 of Set 8 | vesele
# Processing Record 25 of Set 8 | heze
# Processing Record 26 of Set 8 | anadyr
# Processing Record 27 of Set 8 | svetlyy
# Processing Record 28 of Set 8 | natitingou
# Processing Record 29 of Set 8 | yabrud
# Processing Record 30 of Set 8 | dudinka
# Processing Record 31 of Set 8 | whitehorse
# Processing Record 32 of Set 8 | tongling
# Processing Record 33 of Set 8 | dawei
# Processing Record 34 of Set 8 | key west
# Processing Record 35 of Set 8 | langsa
# Processing Record 36 of Set 8 | newtownards
# Processing Record 37 of Set 8 | round rock
# Processing Record 38 of Set 8 | maceio
# Processing Record 39 of Set 8 | shingu
# Processing Record 40 of Set 8 | bignona
# Processing Record 41 of Set 8 | sao filipe
# Processing Record 42 of Set 8 | urumqi
# Processing Record 43 of Set 8 | tutoia
# Processing Record 44 of Set 8 | beringovskiy
# Processing Record 45 of Set 8 | roald
# Processing Record 46 of Set 8 | chengde
# Processing Record 47 of Set 8 | vostok
# Processing Record 48 of Set 8 | bilibino
# Processing Record 49 of Set 8 | dvinskoy
# Processing Record 50 of Set 8 | ijaki
# City not found. Skipping...
# Processing Record 1 of Set 9 | hohhot
# Processing Record 2 of Set 9 | bac giang
# Processing Record 3 of Set 9 | whitecourt
# Processing Record 4 of Set 9 | xaxim
# Processing Record 5 of Set 9 | araouane
# Processing Record 6 of Set 9 | armidale
# Processing Record 7 of Set 9 | ndele
# Processing Record 8 of Set 9 | hamilton
# Processing Record 9 of Set 9 | san policarpo
# Processing Record 10 of Set 9 | coihaique
# Processing Record 11 of Set 9 | dunda
# Processing Record 12 of Set 9 | cockburn town
# Processing Record 13 of Set 9 | pattoki
# Processing Record 14 of Set 9 | manaus
# Processing Record 15 of Set 9 | doka
# Processing Record 16 of Set 9 | iralaya
# Processing Record 17 of Set 9 | qaqortoq
# Processing Record 18 of Set 9 | koslan
# Processing Record 19 of Set 9 | khandbari
# Processing Record 20 of Set 9 | pereslavl-zalesskiy
# Processing Record 21 of Set 9 | vilaka
# Processing Record 22 of Set 9 | tecoanapa
# Processing Record 23 of Set 9 | kerteminde
# Processing Record 24 of Set 9 | luanda
# Processing Record 25 of Set 9 | greenville
# Processing Record 26 of Set 9 | escarcega
# Processing Record 27 of Set 9 | culpeper
# Processing Record 28 of Set 9 | sola
# Processing Record 29 of Set 9 | gannan
# Processing Record 30 of Set 9 | rolim de moura
# City not found. Skipping...
# Processing Record 31 of Set 9 | sitka
# Processing Record 32 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 9 | ako
# Processing Record 34 of Set 9 | matagami
# Processing Record 35 of Set 9 | bayburt
# Processing Record 36 of Set 9 | mto wa mbu
# Processing Record 37 of Set 9 | timra
# Processing Record 38 of Set 9 | fairbanks
# Processing Record 39 of Set 9 | misratah
# Processing Record 40 of Set 9 | yangmei
# Processing Record 41 of Set 9 | vao
# Processing Record 42 of Set 9 | licheng
# Processing Record 43 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 44 of Set 9 | bras-panon
# Processing Record 45 of Set 9 | anloga
# Processing Record 46 of Set 9 | paamiut
# Processing Record 47 of Set 9 | akhaldaba
# Processing Record 48 of Set 9 | karistos
# City not found. Skipping...
# Processing Record 49 of Set 9 | mana
# Processing Record 50 of Set 9 | svetlogorsk
# Processing Record 1 of Set 10 | spring hill
# Processing Record 2 of Set 10 | kaitangata
# Processing Record 3 of Set 10 | tucupita
# Processing Record 4 of Set 10 | blyznyuky
# Processing Record 5 of Set 10 | verkhnyaya balkariya
# Processing Record 6 of Set 10 | faya
# Processing Record 7 of Set 10 | dehloran
# Processing Record 8 of Set 10 | port blair
# Processing Record 9 of Set 10 | buala
# Processing Record 10 of Set 10 | gwadar
# Processing Record 11 of Set 10 | murwillumbah
# Processing Record 12 of Set 10 | ixtapa
# Processing Record 13 of Set 10 | la ronge
# Processing Record 14 of Set 10 | panaba
# Processing Record 15 of Set 10 | vila franca do campo
# Processing Record 16 of Set 10 | riyadh
# Processing Record 17 of Set 10 | deputatskiy
# Processing Record 18 of Set 10 | yulara
# Processing Record 19 of Set 10 | praia da vitoria
# Processing Record 20 of Set 10 | abalak
# Processing Record 21 of Set 10 | eldorado
# Processing Record 22 of Set 10 | pathein
# Processing Record 23 of Set 10 | cabo rojo
# Processing Record 24 of Set 10 | opotiki
# Processing Record 25 of Set 10 | guilin
# Processing Record 26 of Set 10 | bubaque
# Processing Record 27 of Set 10 | elmvale
# Processing Record 28 of Set 10 | pierre
# Processing Record 29 of Set 10 | ninghai
# Processing Record 30 of Set 10 | puerto carreno
# Processing Record 31 of Set 10 | imbituba
# Processing Record 32 of Set 10 | ahar
# Processing Record 33 of Set 10 | lewistown
# Processing Record 34 of Set 10 | geraldton
# Processing Record 35 of Set 10 | troy
# Processing Record 36 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 37 of Set 10 | durango
# Processing Record 38 of Set 10 | taiyuan
# Processing Record 39 of Set 10 | tautira
# Processing Record 40 of Set 10 | hopelchen
# Processing Record 41 of Set 10 | porto nacional
# Processing Record 42 of Set 10 | yuzhno-sukhokumsk
# Processing Record 43 of Set 10 | bochum
# Processing Record 44 of Set 10 | aswan
# Processing Record 45 of Set 10 | rio pomba
# Processing Record 46 of Set 10 | cairns
# Processing Record 47 of Set 10 | yunjinghong
# City not found. Skipping...
# Processing Record 48 of Set 10 | ilebo
# Processing Record 49 of Set 10 | beloha
# Processing Record 50 of Set 10 | banos
# Processing Record 1 of Set 11 | belyy yar
# Processing Record 2 of Set 11 | kambove
# Processing Record 3 of Set 11 | mogzon
# Processing Record 4 of Set 11 | bukama
# Processing Record 5 of Set 11 | lagoa
# Processing Record 6 of Set 11 | neuquen
# Processing Record 7 of Set 11 | ladnun
# Processing Record 8 of Set 11 | cayenne
# Processing Record 9 of Set 11 | neryungri
# Processing Record 10 of Set 11 | san patricio
# Processing Record 11 of Set 11 | kjollefjord
# Processing Record 12 of Set 11 | pafos
# Processing Record 13 of Set 11 | kirakira
# Processing Record 14 of Set 11 | mount isa
# Processing Record 15 of Set 11 | mackay
# Processing Record 16 of Set 11 | fort nelson
# Processing Record 17 of Set 11 | bataipora
# Processing Record 18 of Set 11 | bacuit
# City not found. Skipping...
# Processing Record 19 of Set 11 | norrtalje
# Processing Record 20 of Set 11 | yueyang
# Processing Record 21 of Set 11 | butembo
# Processing Record 22 of Set 11 | noumea
# Processing Record 23 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 11 | mitsamiouli
# Processing Record 25 of Set 11 | dunedin
# Processing Record 26 of Set 11 | campbell river
# Processing Record 27 of Set 11 | caconda
# Processing Record 28 of Set 11 | kaputa
# Processing Record 29 of Set 11 | lazarev
# Processing Record 30 of Set 11 | orocue
# Processing Record 31 of Set 11 | atambua
# Processing Record 32 of Set 11 | kabanjahe
# Processing Record 33 of Set 11 | starkville
# Processing Record 34 of Set 11 | kabugao
# Processing Record 35 of Set 11 | beregovoy
# Processing Record 36 of Set 11 | ballina
# Processing Record 37 of Set 11 | porbandar
# Processing Record 38 of Set 11 | ko samui
# Processing Record 39 of Set 11 | pamyat parizhskoy kommuny
# Processing Record 40 of Set 11 | aklavik
# Processing Record 41 of Set 11 | makung
# City not found. Skipping...
# Processing Record 42 of Set 11 | guasdualito
# Processing Record 43 of Set 11 | portree
# Processing Record 44 of Set 11 | ebersbach
# Processing Record 45 of Set 11 | trat
# Processing Record 46 of Set 11 | wilmington
# Processing Record 47 of Set 11 | maisach
# Processing Record 48 of Set 11 | rio claro
# Processing Record 49 of Set 11 | aykhal
# Processing Record 50 of Set 11 | kushima
# Processing Record 1 of Set 12 | carnarvon
# Processing Record 2 of Set 12 | sabana grande de boya
# Processing Record 3 of Set 12 | panguna
# Processing Record 4 of Set 12 | tazmalt
# Processing Record 5 of Set 12 | mason city
# Processing Record 6 of Set 12 | manokwari
# Processing Record 7 of Set 12 | aldan
# Processing Record 8 of Set 12 | broome
# Processing Record 9 of Set 12 | elko
# Processing Record 10 of Set 12 | avera
# Processing Record 11 of Set 12 | dharchula
# Processing Record 12 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 13 of Set 12 | natal
# Processing Record 14 of Set 12 | turayf
# Processing Record 15 of Set 12 | le port
# Processing Record 16 of Set 12 | casablanca
# Processing Record 17 of Set 12 | lavrentiya
# Processing Record 18 of Set 12 | fare
# Processing Record 19 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 20 of Set 12 | szendro
# Processing Record 21 of Set 12 | melfi
# Processing Record 22 of Set 12 | porto novo
# Processing Record 23 of Set 12 | grottammare
# Processing Record 24 of Set 12 | karpathos
# Processing Record 25 of Set 12 | houma
# Processing Record 26 of Set 12 | sivas
# Processing Record 27 of Set 12 | merauke
# Processing Record 28 of Set 12 | yankton
# Processing Record 29 of Set 12 | warrington
# Processing Record 30 of Set 12 | chulman
# Processing Record 31 of Set 12 | tignere
# Processing Record 32 of Set 12 | atar
# Processing Record 33 of Set 12 | chapais
# Processing Record 34 of Set 12 | kysyl-syr
# Processing Record 35 of Set 12 | rumuruti
# Processing Record 36 of Set 12 | seoul
# Processing Record 37 of Set 12 | kieta
# Processing Record 38 of Set 12 | muisne
# Processing Record 39 of Set 12 | souillac
# Processing Record 40 of Set 12 | phulji
# Processing Record 41 of Set 12 | yakima
# Processing Record 42 of Set 12 | nantucket
# Processing Record 43 of Set 12 | nizwa
# Processing Record 44 of Set 12 | amudat
# Processing Record 45 of Set 12 | zemio
# Processing Record 46 of Set 12 | lannion
# Processing Record 47 of Set 12 | robinson
# Processing Record 48 of Set 12 | kalofer
# Processing Record 49 of Set 12 | parnamirim
# Processing Record 50 of Set 12 | mbala
# Processing Record 1 of Set 13 | oranjemund
# Processing Record 2 of Set 13 | zhangjiakou
# Processing Record 3 of Set 13 | piney green
# Processing Record 4 of Set 13 | teahupoo
# Processing Record 5 of Set 13 | carupano
# Processing Record 6 of Set 13 | yerbogachen
# Processing Record 7 of Set 13 | walvis bay
# Processing Record 8 of Set 13 | carahue
# Processing Record 9 of Set 13 | aksu
# Processing Record 10 of Set 13 | changli
# Processing Record 11 of Set 13 | krasnoselkup
# Processing Record 12 of Set 13 | raahe
# Processing Record 13 of Set 13 | dhidhdhoo
# Processing Record 14 of Set 13 | yandyki
# Processing Record 15 of Set 13 | wanning
# Processing Record 16 of Set 13 | margate
# Processing Record 17 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 18 of Set 13 | bedele
# Processing Record 19 of Set 13 | taoudenni
# Processing Record 20 of Set 13 | port hedland
# Processing Record 21 of Set 13 | haines junction
# Processing Record 22 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 23 of Set 13 | camacha
# Processing Record 24 of Set 13 | sosnovo
# Processing Record 25 of Set 13 | nipawin
# Processing Record 26 of Set 13 | odda
# Processing Record 27 of Set 13 | kununurra
# Processing Record 28 of Set 13 | prince rupert
# Processing Record 29 of Set 13 | puerto escondido
# Processing Record 30 of Set 13 | morgan city
# Processing Record 31 of Set 13 | songjianghe
# Processing Record 32 of Set 13 | dingli
# Processing Record 33 of Set 13 | kashi
# Processing Record 34 of Set 13 | wattegama
# Processing Record 35 of Set 13 | gurskoye
# City not found. Skipping...
# Processing Record 36 of Set 13 | byron bay
# Processing Record 37 of Set 13 | borba
# Processing Record 38 of Set 13 | kazanskaya
# Processing Record 39 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 40 of Set 13 | imeni morozova
# Processing Record 41 of Set 13 | sipe sipe
# Processing Record 42 of Set 13 | alzamay
# Processing Record 43 of Set 13 | alofi
# Processing Record 44 of Set 13 | vidim
# Processing Record 45 of Set 13 | chabahar
# Processing Record 46 of Set 13 | along
# Processing Record 47 of Set 13 | ejea de los caballeros
# Processing Record 48 of Set 13 | deh rawud
# City not found. Skipping...
# Processing Record 49 of Set 13 | ormara
# Processing Record 50 of Set 13 | yerofey pavlovich
# Processing Record 1 of Set 14 | lima
# Processing Record 2 of Set 14 | bo
# City not found. Skipping...
# Processing Record 3 of Set 14 | saint-joseph
# Processing Record 4 of Set 14 | soyo
# Processing Record 5 of Set 14 | shillong
# Processing Record 6 of Set 14 | youghal
# Processing Record 7 of Set 14 | trindade
# Processing Record 8 of Set 14 | tangshan
# Processing Record 9 of Set 14 | adrar
# Processing Record 10 of Set 14 | rafaela
# Processing Record 11 of Set 14 | praia
# Processing Record 12 of Set 14 | cravo norte
# Processing Record 13 of Set 14 | grand gaube
# Processing Record 14 of Set 14 | coihueco
# Processing Record 15 of Set 14 | ternate
# Processing Record 16 of Set 14 | ellisras
# Processing Record 17 of Set 14 | eureka
# Processing Record 18 of Set 14 | biltine
# Processing Record 19 of Set 14 | saint-francois
# Processing Record 20 of Set 14 | emerald
# Processing Record 21 of Set 14 | pacific grove
# Processing Record 22 of Set 14 | muyezerskiy
# Processing Record 23 of Set 14 | tilichiki
# Processing Record 24 of Set 14 | vienna
# Processing Record 25 of Set 14 | sao gabriel da cachoeira
# Processing Record 26 of Set 14 | srednekolymsk
# Processing Record 27 of Set 14 | port hawkesbury
# Processing Record 28 of Set 14 | koungou
# Processing Record 29 of Set 14 | freetown
# Processing Record 30 of Set 14 | sao felix do xingu
# Processing Record 31 of Set 14 | montgomery
# Processing Record 32 of Set 14 | marzuq
# Processing Record 33 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 34 of Set 14 | high level
# Processing Record 35 of Set 14 | neftcala
# Processing Record 36 of Set 14 | tejupilco
# City not found. Skipping...
# Processing Record 37 of Set 14 | jaisalmer
# Processing Record 38 of Set 14 | gawler
# Processing Record 39 of Set 14 | hvolsvollur
# Processing Record 40 of Set 14 | dicabisagan
# Processing Record 41 of Set 14 | chardara
# Processing Record 42 of Set 14 | stornoway
# Processing Record 43 of Set 14 | san jeronimo
# Processing Record 44 of Set 14 | maldonado
# Processing Record 45 of Set 14 | puerto ayacucho
# Processing Record 46 of Set 14 | muncar
# Processing Record 47 of Set 14 | kaseda
# Processing Record 48 of Set 14 | batagay-alyta
# Processing Record 49 of Set 14 | hamina
# Processing Record 50 of Set 14 | iquitos
# Processing Record 1 of Set 15 | buraydah
# Processing Record 2 of Set 15 | kanniyakumari
# Processing Record 3 of Set 15 | torrelavega
# Processing Record 4 of Set 15 | verkhoyansk
# Processing Record 5 of Set 15 | matay
# Processing Record 6 of Set 15 | boone
# Processing Record 7 of Set 15 | winnemucca
# Processing Record 8 of Set 15 | otjimbingwe
# Processing Record 9 of Set 15 | saint-georges
# Processing Record 10 of Set 15 | sinnamary
# Processing Record 11 of Set 15 | liwale
# Processing Record 12 of Set 15 | a
# City not found. Skipping...
# Processing Record 13 of Set 15 | skibbereen
# Processing Record 14 of Set 15 | vienenburg
# Processing Record 15 of Set 15 | bam
# Processing Record 16 of Set 15 | novikovo
# Processing Record 17 of Set 15 | adre
# Processing Record 18 of Set 15 | pervomayskiy
# Processing Record 19 of Set 15 | pochutla
# Processing Record 20 of Set 15 | kokstad
# Processing Record 21 of Set 15 | norsup
# Processing Record 22 of Set 15 | morro bay
# Processing Record 23 of Set 15 | takoradi
# Processing Record 24 of Set 15 | tianpeng
# Processing Record 25 of Set 15 | bartica
# Processing Record 26 of Set 15 | ruteng
# Processing Record 27 of Set 15 | lake forest
# Processing Record 28 of Set 15 | pokhara
# Processing Record 29 of Set 15 | zhanakorgan
# Processing Record 30 of Set 15 | mafinga
# Processing Record 31 of Set 15 | nhulunbuy
# Processing Record 32 of Set 15 | phek
# Processing Record 33 of Set 15 | axim
# Processing Record 34 of Set 15 | camargo
# Processing Record 35 of Set 15 | gao
# Processing Record 36 of Set 15 | shunyi
# Processing Record 37 of Set 15 | bonavista
# Processing Record 38 of Set 15 | acapulco
# Processing Record 39 of Set 15 | mrirt
# City not found. Skipping...
# Processing Record 40 of Set 15 | oriximina
# Processing Record 41 of Set 15 | korhogo
# Processing Record 42 of Set 15 | houston
# Processing Record 43 of Set 15 | lengshuijiang
# Processing Record 44 of Set 15 | mitha tiwana
# Processing Record 45 of Set 15 | sura
# Processing Record 46 of Set 15 | pakxan
# Processing Record 47 of Set 15 | nuevo progreso
# Processing Record 48 of Set 15 | ascope
# Processing Record 49 of Set 15 | bagdarin
# Processing Record 50 of Set 15 | trairi
# Processing Record 1 of Set 16 | piacabucu
# Processing Record 2 of Set 16 | tsumeb
# Processing Record 3 of Set 16 | tuensang
# Processing Record 4 of Set 16 | usolye
# Processing Record 5 of Set 16 | malakal
# Processing Record 6 of Set 16 | zanjan
# Processing Record 7 of Set 16 | sokolo
# Processing Record 8 of Set 16 | umm durman
# City not found. Skipping...
# Processing Record 9 of Set 16 | mehamn
# Processing Record 10 of Set 16 | toftir
# City not found. Skipping...
# Processing Record 11 of Set 16 | powell river
# Processing Record 12 of Set 16 | la sarre
# Processing Record 13 of Set 16 | baie-saint-paul
# Processing Record 14 of Set 16 | razdolinsk
# Processing Record 15 of Set 16 | gambela
# Processing Record 16 of Set 16 | silchar
# Processing Record 17 of Set 16 | george
# Processing Record 18 of Set 16 | urozhayne
# City not found. Skipping...
# Processing Record 19 of Set 16 | gijon
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df=pd.DataFrame(city_data)
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Luderitz      NA -26.6481   15.1594     57.18        75          66
# 1  Constitucion      CL -35.3333  -72.4167     56.17        63           0
# 2     Hithadhoo      MV  -0.6000   73.0833     82.22        73          45
# 3         Airai      TL  -8.9266  125.4092     56.75        58          93
# 4        Hobart      AU -42.8794  147.3294     41.27        85           2
#
#    Wind Speed Current Description
# 0       14.72       broken clouds
# 1       11.32           clear sky
# 2        7.27    scattered clouds
# 3        2.10     overcast clouds
# 4        5.75           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
